# %% [markdown]
# # Census Dataset Brief EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df_census = pd.read_csv("./datasets/census.csv")

df_census.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
df_census.describe()
# Out:
#        District_code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#             Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# count  6.400000e+02  6.400000e+02    6.400000e+02        6.400000e+02
# mean   7.529514e+05  5.186561e+05    2.342953e+05        1.856387e+05
# ...

# %%
df_census.count()
# Out:
# District_code           640
# State_name              640
# District_name           640
# Population              640
# Male                    640
# Female                  640
# Literate                640
# Workers                 640
# Male_Workers            640
# Female_Workers          640
# Cultivator_Workers      640
# Agricultural_Workers    640
# Household_Workers       640
# Hindus                  640
# Muslims                 640
# Christians              640
# Sikhs                   640
# Buddhists               640
# Jains                   640
# Secondary_Education     640
# Higher_Education        640
# Graduate_Education      640
# Age_Group_0_29          640
# Age_Group_30_49         640
# Age_Group_50            640
# dtype: int64

# %%
df_census.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Population              0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# dtype: int64

# %% [markdown]
# ## 1. Hide the indices of the dataframe.

# %%
df_census.head().style.hide(axis='index')

# legacy syntax:
# df_census.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_67947">
#   <thead>
#     <tr>
#       <th id="T_67947_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_67947_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_67947_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_67947_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_67947_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_67947_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_67947_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_67947_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_67947_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
#       <th id="T_67947_level0_col9" class="col_heading level0 col9" >Female_Workers</th>
# ...

# %% [markdown]
# ## 2. Set the caption / heading on the dataframe.

# %%
df_census.head().style.set_caption('2011 India census Dataset')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e560">
#   <caption>2011 India census Dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e560_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_6e560_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_6e560_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_6e560_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_6e560_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_6e560_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_6e560_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_6e560_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_6e560_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# ## 3. Show the records related with the districts - New Delhi , Lucknow , Jaipur.

# %%
df_census.query("District_name == 'New Delhi' or District_name == 'Lucknow' or District_name == 'Jaipur'")
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %%
df_census[(df_census['District_name'] == 'New Delhi') | (df_census['District_name'] == 'Lucknow') | (df_census['District_name'] == 'Jaipur')]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %%
df_census[df_census['District_name'].isin(['New Delhi', 'Lucknow', 'Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# ## 4. Calculate state-wise :

# %% [markdown]
# ### 4.1. Total number of population.

# %%
df_census['Population'].groupby(df_census['State_name']).sum().sort_values(ascending=False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
df_census.pivot_table(index='State_name',
                      values='Population',
                      aggfunc='sum').sort_values(by='Population', ascending=False)
# Out:
#                              Population
# State_name
# UTTAR PRADESH                 199812341
# MAHARASHTRA                   112374333
# BIHAR                         104099452
# WEST BENGAL                    91276115
# ANDHRA PRADESH                 84580777
# MADHYA PRADESH                 72626809
# TAMIL NADU                     72147030
# RAJASTHAN                      68548437
# KARNATAKA                      61095297
# GUJARAT                        60439692
# ORISSA                         41974218
# KERALA                         33406061
# JHARKHAND                      32988134
# ASSAM                          31205576
# PUNJAB                         27743338
# CHHATTISGARH                   25545198
# HARYANA                        25351462
# NCT OF DELHI                   16787941
# JAMMU AND KASHMIR              12541302
# UTTARAKHAND                    10086292
# HIMACHAL PRADESH                6864602
# TRIPURA                         3673917
# ...

# %% [markdown]
# ### 4.2. Total no. of the population with different religions.

# %%
df_census.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
df_census.groupby('State_name')[['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains']].sum().sort_values(by='Christians', ascending=False)
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# KERALA                        18282492   8873472     6141269      3814
# TAMIL NADU                    63188168   4229479     4418331     14601
# MEGHALAYA                       342078    130399     2213027      3045
# NAGALAND                        173054     48963     1739651      1890
# JHARKHAND                     22376051   4793994     1418608     71422
# MANIPUR                        1181876    239836     1179043      1527
# ASSAM                         19180759  10679345     1165867     20672
# ORISSA                        39300341    911670     1161708     21991
# KARNATAKA                     51317472   7893065     1142647     28773
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# MAHARASHTRA                   89703057  12971152     1080073    223247
# MIZORAM                          30136     14832      956331       286
# ...

# %% [markdown]
# ## 5. How many Male Workers were there in Maharashtra state?

# %%
df_census.sample(5)
# Out:
#      District_code         State_name  District_name  Population     Male  \
# 17              18  JAMMU AND KASHMIR       Kishtwar      230696   120165
# 253            254  ARUNACHAL PRADESH          Tirap      111975    57604
# 557            558          KARNATAKA          Bidar     1703300   870665
# 614            615         TAMIL NADU     Perambalur      565223   282157
# 543            544     ANDHRA PRADESH  Visakhapatnam     4290589  2138910
#
#       Female  Literate  Workers  Male_Workers  Female_Workers  ...  \
# 17    110531    107506    82974         56779           26195  ...
# 253    54371     47974    50169         27545           22624  ...
# 557   832635   1042673   702608        459050          243558  ...
# 614   283066    375823   299726        162639          137087  ...
# 543  2151679   2568249  1889879       1239064          650815  ...
#
#      Christians  Sikhs  Buddhists  Jains  Secondary_Education  \
# ...

# %%
df_census[df_census['State_name'] == 'MAHARASHTRA']['Male_Workers'].sum()
# Out:
# 32616875

# %% [markdown]
# ## 6. How to set a column values as index of the dataframe?

# %%
df_census.set_index('District_code')
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %% [markdown]
# ## 7. Add a Suffix to the column names.

# %%
df_census.add_suffix('_suffix')
# Out:
#      District_code_suffix            State_name_suffix  \
# 0                       1            JAMMU AND KASHMIR
# 1                       2            JAMMU AND KASHMIR
# 2                       3            JAMMU AND KASHMIR
# 3                       4            JAMMU AND KASHMIR
# 4                       5            JAMMU AND KASHMIR
# ..                    ...                          ...
# 635                   636                  PONDICHERRY
# 636                   637                  PONDICHERRY
# 637                   638  ANDAMAN AND NICOBAR ISLANDS
# 638                   639  ANDAMAN AND NICOBAR ISLANDS
# 639                   640  ANDAMAN AND NICOBAR ISLANDS
#
#           District_name_suffix  Population_suffix  Male_suffix  Female_suffix  \
# 0                      Kupwara             870354       474190         396164
# 1                       Badgam             753745       398041         355704
# ...

# %% [markdown]
# ## 8. Add a Prefix to the column names.

# %%
df_census.add_prefix('prefix_')
# Out:
#      prefix_District_code            prefix_State_name  \
# 0                       1            JAMMU AND KASHMIR
# 1                       2            JAMMU AND KASHMIR
# 2                       3            JAMMU AND KASHMIR
# 3                       4            JAMMU AND KASHMIR
# 4                       5            JAMMU AND KASHMIR
# ..                    ...                          ...
# 635                   636                  PONDICHERRY
# 636                   637                  PONDICHERRY
# 637                   638  ANDAMAN AND NICOBAR ISLANDS
# 638                   639  ANDAMAN AND NICOBAR ISLANDS
# 639                   640  ANDAMAN AND NICOBAR ISLANDS
#
#           prefix_District_name  prefix_Population  prefix_Male  prefix_Female  \
# 0                      Kupwara             870354       474190         396164
# 1                       Badgam             753745       398041         355704
# ...
