# %% [markdown]
# # Project 6 - Case Study 6 - Udemy Courses Dataset

# %% [markdown]
# ## Key concepts
#
# 1.  parse_dates:  parse_dates parameter for read_csv which allows you to define the names of the columns you want to be treated as dates or datetimes:
#
#
# 2. value_counts()  : The value_counts() method returns a Series containing the counts of unique values
#
#
# 3. Countplot:  countplot() method is used to show the counts of observations in each categorical bin using bars.
#
#
# 4. Barplot(): Bar plots or graphs are useful for displaying relationships between categorical data and at least one numerical variable.

# %%
# import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# load the dataset
df_udemy = pd.read_csv("./datasets/06_Case_06_udemy_courses.csv", parse_dates=['published_timestamp'])

# %%
df_udemy.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %% [markdown]
# ## 1. Display Top 10 Rows of The Dataset

# %%
df_udemy.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %% [markdown]
# ## 2. Check Last 5 Rows of The Dataset

# %%
df_udemy.tail(5)
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# ## 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
print("Data shape :", df_udemy.shape)
print("Rows :", df_udemy.shape[0])
print("Columns :", df_udemy.shape[1])
# Out:
# Data shape : (3678, 12)
# Rows : 3678
# Columns : 12

# %% [markdown]
# ## 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df_udemy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# ## 5. Check Null Values In The Dataset

# %%
print("Are there any missing values?", df_udemy.isnull().values.any())
# Out:
# Are there any missing values? False

# %%
df_udemy.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(df_udemy.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## 6. Check For Duplicate Data and Drop Them

# %%
duplicates = df_udemy.duplicated().any()

print("Are there any duplicates in the dataset?", duplicates)
# Out:
# Are there any duplicates in the dataset? False

# %%
df_udemy = df_udemy.drop_duplicates()

# %%
# check
print("Are there any duplicates in the dataset?", duplicates)
# Out:
# Are there any duplicates in the dataset? False

# %% [markdown]
# ## 7. Find Out Number of Courses Per Subjects

# %%
df_udemy.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance
# 1 2017-03-09 16:34:20+00:00  Business Finance

# %%
df_udemy['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
sns.countplot(x='subject', data=df_udemy, order=df_udemy['subject'].value_counts().index)
plt.xlabel("Subjects", fontsize=13)
plt.ylabel("Number of courses per subject", fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 8. For Which Levels, Udemy Courses Providing The Courses

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df_udemy['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.countplot(x='level', data=df_udemy, order=df_udemy['level'].value_counts().index)
plt.xlabel("Level", fontsize=13)
plt.ylabel("Number of expertise levels", fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 9. Display The Count of Paid and Free Courses

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df_udemy['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(x='is_paid', data=df_udemy, order=df_udemy['is_paid'].value_counts().index)
plt.xlabel("Paid/Free courses", fontsize=13)
plt.ylabel("Number of paid/free courses", fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 10. Which Course Has More Lectures (Free or Paid)?

# %%
df_udemy[['course_id', 'num_subscribers', 'num_reviews', 'num_lectures']].groupby(df_udemy['is_paid']).mean()
# Out:
#              course_id  num_subscribers  num_reviews  num_lectures
# is_paid
# False    691446.970968     11533.951613   425.929032     21.416129
# True     674463.946163      2421.270077   131.516359     41.866746

# %% [markdown]
# ## 11. Which Courses Have A Higher Number of Subscribers Free or Paid?

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.barplot(x='is_paid', y='num_subscribers', data=df_udemy)
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %% [markdown]
# ## 12. Which Level Has The Highest Number of Subscribers?

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.barplot(x='level', y='num_subscribers', data=df_udemy, order=df_udemy['level'].value_counts().index)
plt.xlabel("Course level", fontsize=13)
plt.ylabel("Number of subscribers", fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 13. Find Most Popular Course Title

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df_udemy['num_subscribers'].max() == df_udemy['num_subscribers']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# 3677    False
# Name: num_subscribers, Length: 3672, dtype: bool

# %%
df_udemy[df_udemy['num_subscribers'] == df_udemy['num_subscribers'].max()]
# Out:
#       course_id                          course_title  \
# 2827      41295  Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development

# %%
df_udemy[df_udemy['num_subscribers'] == df_udemy['num_subscribers'].max()]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# ## 14. Display 10 Most Popular Courses As Per Number of Subscribers

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
top_10_subscribers = df_udemy.sort_values(by="num_subscribers", ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers', y='course_title', data=top_10_subscribers)
plt.xlabel("Number of subscribers", fontsize=13)
plt.ylabel("Course title", fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 15. Find The Course Which Has The Highest Number of Reviews.

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
course_subject_by_reviews = df_udemy.sort_values(by='num_reviews', ascending=False)

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='subject', y='num_reviews', data=df_udemy, order=course_subject_by_reviews_index)
plt.xlabel("Subject", fontsize=13)
plt.ylabel("Number of reviews", fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Similarly:

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='subject', y='num_reviews', data=course_subject_by_reviews)
plt.xlabel("Subject", fontsize=13)
plt.ylabel("Number of reviews", fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 16. Does Price Affect the Number of Reviews?

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 5))
sns.scatterplot(x='price', y='num_reviews', data=df_udemy)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %% [markdown]
# ## 17. Find Total Number of Courses Related To Python

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df_udemy[df_udemy['course_title'].str.contains('python', case=False)]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
len(df_udemy[df_udemy['course_title'].str.contains('python', case=False)])
# Out:
# 29

# %% [markdown]
# ## 18. Display 10 Most Popular Python Courses As Per Number of Subscribers

# %%
python_top_10 = df_udemy[df_udemy['course_title'].str.contains('python', case=False)].sort_values(by='num_subscribers', ascending=False).head(10)

# %%
sns.barplot(x='num_subscribers', y='course_title', data=python_top_10)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# ## 19. In Which Year The Highest Number of Courses Were Posted?

# %%
df_udemy.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df_udemy['year'] = df_udemy['published_timestamp'].dt.year

# %%
sns.countplot(x='year', data=df_udemy)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# ## 20. Display Category-Wise Count of Posted Subjects [Year Wise]

# %%
df_udemy.groupby('year')['subject'].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Web Development        223
#       Business Finance       223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64

# %% [markdown]
# Similarly

# %%
df_udemy['subject'].groupby(df_udemy['year']).value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Web Development        223
#       Business Finance       223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
