# %% [markdown]
# # Dataframes concatenations - Part 3 - Parameters

# %% [markdown]
# Concat parameters:
#
# axis=0, <br>
# ignore_index (bool) = False, <br>
# join='outer', <br>
# keys=None, <br>
# names=None, <br>
# verify_integrity (bool) = False, <br>
# sort (bool) = False, <br>

# %%
import pandas as pd

# %%
data1 = {
    'Name' : ['Paul', 'Aaron', 'Krista', 'Veronica', 'Paxton', 'Madison', 'Aurora'],
    'Score': [98, 89, 99, 87, 90, 83, 82]
}

data2 = {
    'Name' : ['Robert', 'Craig', 'Frank', 'Jordyn', 'Isabel'],
    'Score': [98, 89, 99, 97, 97]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#        Name  Score
# 0      Paul     98
# 1     Aaron     89
# 2    Krista     99
# 3  Veronica     87
# 4    Paxton     90
# 5   Madison     83
# 6    Aurora     82

# %%
df2
# Out:
#      Name  Score
# 0  Robert     98
# 1   Craig     89
# 2   Frank     99
# 3  Jordyn     97
# 4  Isabel     97

# %% [markdown]
# ## Basic concat

# %%
pd.concat([df1, df2], axis=0)
# Out:
#        Name  Score
# 0      Paul     98
# 1     Aaron     89
# 2    Krista     99
# 3  Veronica     87
# 4    Paxton     90
# 5   Madison     83
# 6    Aurora     82
# 0    Robert     98
# 1     Craig     89
# 2     Frank     99
# 3    Jordyn     97
# 4    Isabel     97

# %% [markdown]
# ## Using keys parameter

# %% [markdown]
# Vertically

# %%
pd.concat([df1, df2], axis=0, keys=['DF1', 'DF2'])
# Out:
#            Name  Score
# DF1 0      Paul     98
#     1     Aaron     89
#     2    Krista     99
#     3  Veronica     87
#     4    Paxton     90
#     5   Madison     83
#     6    Aurora     82
# DF2 0    Robert     98
#     1     Craig     89
#     2     Frank     99
#     3    Jordyn     97
#     4    Isabel     97

# %% [markdown]
# Horizontally

# %%
pd.concat([df1, df2], axis=1, keys=['DF1', 'DF2'])
# Out:
#         DF1           DF2
#        Name Score    Name Score
# 0      Paul    98  Robert  98.0
# 1     Aaron    89   Craig  89.0
# 2    Krista    99   Frank  99.0
# 3  Veronica    87  Jordyn  97.0
# 4    Paxton    90  Isabel  97.0
# 5   Madison    83     NaN   NaN
# 6    Aurora    82     NaN   NaN

# %% [markdown]
# ## Store concatenated dataframe to a variable and make hierarchical dataframe

# %%
data = pd.concat([df1, df2], axis=0, keys=['DF1', 'DF2'])

data
# Out:
#            Name  Score
# DF1 0      Paul     98
#     1     Aaron     89
#     2    Krista     99
#     3  Veronica     87
#     4    Paxton     90
#     5   Madison     83
#     6    Aurora     82
# DF2 0    Robert     98
#     1     Craig     89
#     2     Frank     99
#     3    Jordyn     97
#     4    Isabel     97

# %% [markdown]
# ## Accessing the values in the dataframe by rows/columns

# %%
data.loc['DF1']

# %% [markdown]
# Or

# %%
data.loc['DF1', :]
# Out:
#        Name  Score
# 0      Paul     98
# 1     Aaron     89
# 2    Krista     99
# 3  Veronica     87
# 4    Paxton     90
# 5   Madison     83
# 6    Aurora     82

# %% [markdown]
# Or

# %%
data.loc['DF2']
# Out:
#      Name  Score
# 0  Robert     98
# 1   Craig     89
# 2   Frank     99
# 3  Jordyn     97
# 4  Isabel     97

# %%
data.loc['DF2', :]
# Out:
#      Name  Score
# 0  Robert     98
# 1   Craig     89
# 2   Frank     99
# 3  Jordyn     97
# 4  Isabel     97

# %% [markdown]
# ## Add names to hierarchical index

# %%
pd.concat([df1, df2], keys=['DF1', 'DF2'], names=['Level_1', 'Level_2'])
# Out:
#                      Name  Score
# Level_1 Level_2
# DF1     0            Paul     98
#         1           Aaron     89
#         2          Krista     99
#         3        Veronica     87
#         4          Paxton     90
#         5         Madison     83
#         6          Aurora     82
# DF2     0          Robert     98
#         1           Craig     89
#         2           Frank     99
#         3          Jordyn     97
#         4          Isabel     97

# %% [markdown]
# ## Verify integrity parameter (avoid duplicate indices)

# %% [markdown]
# `verify_integrity=False` (bool, default=False)

# %%
data1 = {
    'Name' : ['Paul', 'Aaron', 'Krista', 'Veronica', 'Paxton'],
    'Score': [98, 89, 99, 87, 90]
}

data2 = {
    'Name' : ['Robert', 'Craig', 'Frank', 'Jordyn', 'Isabel'],
    'Score': [98, 89, 99, 97, 97]
}

df1 = pd.DataFrame(data1, index=[i for i in range(5)])
df2 = pd.DataFrame(data2, index=[i for i in range(5)])

# %%
df1
# Out:
#        Name  Score
# 0      Paul     98
# 1     Aaron     89
# 2    Krista     99
# 3  Veronica     87
# 4    Paxton     90

# %%
df2
# Out:
#      Name  Score
# 0  Robert     98
# 1   Craig     89
# 2   Frank     99
# 3  Jordyn     97
# 4  Isabel     97

# %% [markdown]
# Verify integrity (checks if a dataframe contans duplicated indices) <br>
#
# For the dataframe above we have duplicated indices such that in df1 we have 0, 1, 2, 3, 4 <br>
# and df2 we also have 0, 1, 2, 3, 4, as indices. <br>
#
# Because of this, `verify_integrity=True` should give an error

# %%
pd.concat([df1, df2], axis=0, verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 pd.concat([df1, df2], axis=0, verify_integrity=True)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:563, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     560 self.verify_integrity = verify_integrity
#     561 self.copy = copy
# --> 563 self.new_axes = self._get_new_axes()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:633, in _Concatenator._get_new_axes(self)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
# --> 633     return [
#     634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:634, in <listcomp>(.0)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
#     633     return [
# --> 634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:697, in _Concatenator._get_concat_axis(self)
#     692 else:
#     693     concat_axis = _make_concat_multiindex(
#     694         indexes, self.keys, self.levels, self.names
#     695     )
# --> 697 self._maybe_check_integrity(concat_axis)
#     699 return concat_axis
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:705, in _Concatenator._maybe_check_integrity(self, concat_index)
#     703 if not concat_index.is_unique:
#     704     overlap = concat_index[concat_index.duplicated()].unique()
# --> 705     raise ValueError(f"Indexes have overlapping values: {overlap}")
#
# ValueError: Indexes have overlapping values: Index([0, 1, 2, 3, 4], dtype='int64')

# %% [markdown]
# if you don't want the error, then you should set different values as indices to different datasets

# %% [markdown]
# Similar thing will happen if we set the axis to 1 (`axis=1`). <br>
# Because in both dataframes we have the exact same column names as horizontal indices. ('Names' and 'Score')

# %%
pd.concat([df1, df2], axis=1, verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 pd.concat([df1, df2], axis=1, verify_integrity=True)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:563, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     560 self.verify_integrity = verify_integrity
#     561 self.copy = copy
# --> 563 self.new_axes = self._get_new_axes()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:633, in _Concatenator._get_new_axes(self)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
# --> 633     return [
#     634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:634, in <listcomp>(.0)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
#     633     return [
# --> 634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:697, in _Concatenator._get_concat_axis(self)
#     692 else:
#     693     concat_axis = _make_concat_multiindex(
#     694         indexes, self.keys, self.levels, self.names
#     695     )
# --> 697 self._maybe_check_integrity(concat_axis)
#     699 return concat_axis
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py:705, in _Concatenator._maybe_check_integrity(self, concat_index)
#     703 if not concat_index.is_unique:
#     704     overlap = concat_index[concat_index.duplicated()].unique()
# --> 705     raise ValueError(f"Indexes have overlapping values: {overlap}")
#
# ValueError: Indexes have overlapping values: Index(['Name', 'Score'], dtype='object')

# %% [markdown]
# See, we get an error

# %% [markdown]
# ## Sort parameter

# %% [markdown]
# Sort columns if we are adding rows, and sort rows if we are adding columns

# %%
data1 = {
    'Name' : ['Paul', 'Aaron', 'Krista', 'Veronica', 'Paxton'],
    'Score': [98, 89, 99, 87, 90]
}

data2 = {
    'Name' : ['Robert', 'Jordyn', 'Isabel'],
    'Grades': ['AA', 'AA', 'AA']
}

df1 = pd.DataFrame(data1, index=[i for i in range(5)])
df2 = pd.DataFrame(data2, index=[i for i in range(3)])

# %%
df1
# Out:
#        Name  Score
# 0      Paul     98
# 1     Aaron     89
# 2    Krista     99
# 3  Veronica     87
# 4    Paxton     90

# %%
df2
# Out:
#      Name Grades
# 0  Robert     AA
# 1  Jordyn     AA
# 2  Isabel     AA

# %%
pd.concat([df1, df2], axis=0)
# Out:
#        Name  Score Grades
# 0      Paul   98.0    NaN
# 1     Aaron   89.0    NaN
# 2    Krista   99.0    NaN
# 3  Veronica   87.0    NaN
# 4    Paxton   90.0    NaN
# 0    Robert    NaN     AA
# 1    Jordyn    NaN     AA
# 2    Isabel    NaN     AA

# %% [markdown]
# Again, we are sorting columns if we are adding rows, and vice versa

# %% [markdown]
# Using `axis=0`, we get:

# %%
pd.concat([df1, df2], axis=0, sort=True)
# Out:
#   Grades      Name  Score
# 0    NaN      Paul   98.0
# 1    NaN     Aaron   89.0
# 2    NaN    Krista   99.0
# 3    NaN  Veronica   87.0
# 4    NaN    Paxton   90.0
# 0     AA    Robert    NaN
# 1     AA    Jordyn    NaN
# 2     AA    Isabel    NaN

# %% [markdown]
# Using `axis=1`, we get:

# %%
pd.concat([df1, df2], axis=1, sort=True)
# Out:
#        Name  Score    Name Grades
# 0      Paul     98  Robert     AA
# 1     Aaron     89  Jordyn     AA
# 2    Krista     99  Isabel     AA
# 3  Veronica     87     NaN    NaN
# 4    Paxton     90     NaN    NaN

# %% [markdown]
# Our dataframe is sorted by index values
