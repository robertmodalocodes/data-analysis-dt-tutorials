# %% [markdown]
# # Merge Pandas Dataframes

# %%
import pandas as pd

# %%
data1 = {'key' : ['k0', 'k1', 'k2', 'k3', 'k4'],
         'Name': ['Paula', 'Alexis', 'Jordan', 'Trent', 'Ulysses']}

data2 = {'key' : ['k0', 'k1', 'k2', 'k3', 'k4'],
         'Score': [96, 98, 94, 92, 92]}

df1 = pd.DataFrame(data1)

df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#   key     Name
# 0  k0    Paula
# 1  k1   Alexis
# 2  k2   Jordan
# 3  k3    Trent
# 4  k4  Ulysses

# %%
df2
# Out:
#   key  Score
# 0  k0     96
# 1  k1     98
# 2  k2     94
# 3  k3     92
# 4  k4     92

# %% [markdown]
# ## Merge left using on

# %% [markdown]
# Always remember that the reference column as a value of `on` must be the exact same in both dataframes
#
# We can pass label or list as the parameter

# %%
pd.merge(left=df1, right=df2, on='key')
# Out:
#   key     Name  Score
# 0  k0    Paula     96
# 1  k1   Alexis     98
# 2  k2   Jordan     94
# 3  k3    Trent     92
# 4  k4  Ulysses     92

# %%
pd.merge(df1, df2, on='key')
# Out:
#   key     Name  Score
# 0  k0    Paula     96
# 1  k1   Alexis     98
# 2  k2   Jordan     94
# 3  k3    Trent     92
# 4  k4  Ulysses     92

# %%
pd.merge(df2, df1, on='key')
# Out:
#   key  Score     Name
# 0  k0     96    Paula
# 1  k1     98   Alexis
# 2  k2     94   Jordan
# 3  k3     92    Trent
# 4  k4     92  Ulysses

# %% [markdown]
# Label : single key <br>
# List : multiple keys

# %%
data1 = {'key1' : ['k0', 'k1', 'k2', 'k3', 'k4'],
         'key2' : ['k0', 'k1', 'K0', 'k1', 'k2'],
         'Name': ['Paula', 'Alexis', 'Jordan', 'Trent', 'Ulysses']}

data2 = {'key1' : ['k0', 'k1', 'k2', 'k3', 'k4'],
         'key2' : ['k0', 'k1', 'K0', 'k1', 'k2'],
         'Score': [96, 98, 94, 92, 92]}

df1 = pd.DataFrame(data1)

df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#   key1 key2     Name
# 0   k0   k0    Paula
# 1   k1   k1   Alexis
# 2   k2   K0   Jordan
# 3   k3   k1    Trent
# 4   k4   k2  Ulysses

# %%
df2
# Out:
#   key1 key2  Score
# 0   k0   k0     96
# 1   k1   k1     98
# 2   k2   K0     94
# 3   k3   k1     92
# 4   k4   k2     92

# %%
pd.merge(df1, df2, on=['key1', 'key2'])
# Out:
#   key1 key2     Name  Score
# 0   k0   k0    Paula     96
# 1   k1   k1   Alexis     98
# 2   k2   K0   Jordan     94
# 3   k3   k1    Trent     92
# 4   k4   k2  Ulysses     92

# %% [markdown]
# ## Inner merge/join

# %% [markdown]
# how ('left', 'right', 'outer', 'inner')

# %%
data1 = {'key' : ['k0', 'k1', 'k2', 'k5', 'k6'],
         'Name': ['Paula', 'Alexis', 'Jordan', 'Trent', 'Ulysses']}

data2 = {'key' : ['k0', 'k1', 'k2', 'k3', 'k4'],
         'Score': [96, 98, 94, 92, 92]}

df1 = pd.DataFrame(data1)

df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#   key     Name
# 0  k0    Paula
# 1  k1   Alexis
# 2  k2   Jordan
# 3  k5    Trent
# 4  k6  Ulysses

# %%
df2
# Out:
#   key  Score
# 0  k0     96
# 1  k1     98
# 2  k2     94
# 3  k3     92
# 4  k4     92

# %%
pd.merge(df1, df2, on="key")
# Out:
#   key    Name  Score
# 0  k0   Paula     96
# 1  k1  Alexis     98
# 2  k2  Jordan     94

# %%
pd.merge(df1, df2, on='key', how='inner')
# Out:
#   key    Name  Score
# 0  k0   Paula     96
# 1  k1  Alexis     98
# 2  k2  Jordan     94

# %%
pd.merge(df1, df2, on='key', how='outer')
# Out:
#   key     Name  Score
# 0  k0    Paula   96.0
# 1  k1   Alexis   98.0
# 2  k2   Jordan   94.0
# 3  k5    Trent    NaN
# 4  k6  Ulysses    NaN
# 5  k3      NaN   92.0
# 6  k4      NaN   92.0

# %%
pd.merge(df1, df2, on='key', how='left')
# Out:
#   key     Name  Score
# 0  k0    Paula   96.0
# 1  k1   Alexis   98.0
# 2  k2   Jordan   94.0
# 3  k5    Trent    NaN
# 4  k6  Ulysses    NaN

# %%
pd.merge(df1, df2, on='key', how='right')
# Out:
#   key    Name  Score
# 0  k0   Paula     96
# 1  k1  Alexis     98
# 2  k2  Jordan     94
# 3  k3     NaN     92
# 4  k4     NaN     92

# %% [markdown]
# ## Indicator parameter

# %% [markdown]
# Indocator (bool, string)

# %%
pd.merge(df1, df2, on='key', how='outer', indicator=True)
# Out:
#   key     Name  Score      _merge
# 0  k0    Paula   96.0        both
# 1  k1   Alexis   98.0        both
# 2  k2   Jordan   94.0        both
# 3  k5    Trent    NaN   left_only
# 4  k6  Ulysses    NaN   left_only
# 5  k3      NaN   92.0  right_only
# 6  k4      NaN   92.0  right_only

# %%
pd.merge(df1, df2, on='key', how='outer', indicator='Source')
# Out:
#   key     Name  Score      Source
# 0  k0    Paula   96.0        both
# 1  k1   Alexis   98.0        both
# 2  k2   Jordan   94.0        both
# 3  k5    Trent    NaN   left_only
# 4  k6  Ulysses    NaN   left_only
# 5  k3      NaN   92.0  right_only
# 6  k4      NaN   92.0  right_only

# %% [markdown]
# ## `left_index` and `right_index`

# %%
data1 = {'key' : ['k0', 'k1', 'k2', 'k3', 'k4'],
         'Name': ['Paula', 'Alexis', 'Jordan', 'Trent', 'Ulysses']}

data2 = {'key' : ['k5', 'k6', 'k7', 'k8', 'k9'],
         'Score': [96, 98, 94, 92, 92]}

df1 = pd.DataFrame(data1)

df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#   key     Name
# 0  k0    Paula
# 1  k1   Alexis
# 2  k2   Jordan
# 3  k3    Trent
# 4  k4  Ulysses

# %%
df2
# Out:
#   key  Score
# 0  k5     96
# 1  k6     98
# 2  k7     94
# 3  k8     92
# 4  k9     92

# %%
pd.merge(df1, df2)
# Out:
# Empty DataFrame
# Columns: [key, Name, Score]
# Index: []

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#   key_x     Name key_y  Score
# 0    k0    Paula    k5     96
# 1    k1   Alexis    k6     98
# 2    k2   Jordan    k7     94
# 3    k3    Trent    k8     92
# 4    k4  Ulysses    k9     92

# %% [markdown]
# ## suffix

# %%
data1 = {'key' : ['k0', 'k1', 'k2', 'k3', 'k4'],
         'Name': ['Paula', 'Alexis', 'Jordan', 'Trent', 'Ulysses']}

data2 = {'key' : ['k0', 'k1', 'k2', 'k3', 'k4'],
         'Name': ['Paula', 'Alexis', 'Jordan', 'Trent', 'Ulysses']}

df1 = pd.DataFrame(data1)

df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#   key     Name
# 0  k0    Paula
# 1  k1   Alexis
# 2  k2   Jordan
# 3  k3    Trent
# 4  k4  Ulysses

# %%
df2
# Out:
#   key     Name
# 0  k0    Paula
# 1  k1   Alexis
# 2  k2   Jordan
# 3  k3    Trent
# 4  k4  Ulysses

# %%
pd.merge(df1, df2, on='key')
# Out:
#   key   Name_x   Name_y
# 0  k0    Paula    Paula
# 1  k1   Alexis   Alexis
# 2  k2   Jordan   Jordan
# 3  k3    Trent    Trent
# 4  k4  Ulysses  Ulysses

# %%
pd.merge(df1, df2, on='key', suffixes=('_leftDF', '_rightDF'))
# Out:
#   key Name_leftDF Name_rightDF
# 0  k0       Paula        Paula
# 1  k1      Alexis       Alexis
# 2  k2      Jordan       Jordan
# 3  k3       Trent        Trent
# 4  k4     Ulysses      Ulysses
